# %%
from func import *

from scipy import stats

# %% [markdown]
# ## Load random and nonrandom samples

# %%
table = pd.read_hdf("./id_table.hdf")

# %%
random_counters = get_counters(10, protocol="semanticType")

# %%
random_counter = list()
for counter_list in random_counters:
    random_counter = random_counter + counter_list

# %%
real_counter = get_sem_cat_counter_list(table, "real", protocol="semanticType")

# %%
print(len(random_counter), len(real_counter))
# Out:
# 4030 403

# %% [markdown]
# ## Kolmogorov-Smirnov test

# %%
def test_if_the_same(random_counter, real_counter, cat):
    random_sample = [counter[cat] for counter in random_counter]
    real_sample = [counter[cat] for counter in real_counter]
    return stats.ks_2samp(random_sample, real_sample)

# %%
cats = set()
for counter in real_counter + random_counteR:
    cats = cats | set(counter.keys())

# %%
print(cats)
# Out:
# {'Congenital Abnormality', 'Functional Concept', 'T9998', 'Carbohydrate', 'Injury or Poisoning', 'Food', 'Indicator, Reagent, or Diagnostic Aid', 'Daily or Recreational Activity', 'Mental or Behavioral Dysfunction', 'Vertebrate', 'Cell Function', 'Body Location or Region', 'Cell Component', 'Pharmacologic Substance', 'Animal', 'Classification', 'Natural Phenomenon or Process', 'Intellectual Product', 'Phenomenon or Process', 'Amino Acid, Peptide, or Protein', 'Amphibian', 'Health Care Activity', 'Gene or Genome', 'Finding', 'Acquired Abnormality', 'Laboratory Procedure', 'Activity', 'Molecular Sequence', 'Body System', 'Biologic Function', 'Educational Activity', 'Idea or Concept', 'Nucleotide Sequence', 'Molecular Biology Research Technique', 'Research Activity', 'Biologically Active Substance', 'Occupation or Discipline', 'Vitamin', 'Fungus', 'Embryonic Structure', 'Experimental Model of Disease', 'Human-caused Phenomenon or Process', 'Mental Process', 'Neuroreactive Substance or Biogenic Amine', 'Archaeon', 'Chemical Viewed Structurally', 'Element, Ion, or Isotope', 'Genetic Function', 'Body Space or Junction', 'Cell or Molecular Dysfunction', 'Manufactured Object', 'Therapeutic or Preventive Procedure', 'Organophosphorus Compound', 'Substance', 'Diagnostic Procedure', 'Amino Acid Sequence', 'Bacterium', 'Eukaryote', 'Chemical Viewed Functionally', 'Population Group', 'Medical Device', 'Inorganic Chemical', 'Group', 'Antibiotic', 'Molecular Function', 'Family Group', 'Bird', 'Individual Behavior', 'Temporal Concept', 'Organism Function', 'Organ or Tissue Function', 'Cell', 'Clinical Attribute', 'Eicosanoid', 'Tissue', 'Occupational Activity', 'Organism', 'Pathologic Function', 'Lipid', 'Body Substance', 'Professional or Occupational Group', 'Fish', 'Body Part, Organ, or Organ Component', 'Biomedical Occupation or Discipline', 'Enzyme', 'Mammal', 'Fully Formed Anatomical Structure', 'Immunologic Factor', 'Hormone', 'Nucleic Acid, Nucleoside, or Nucleotide', 'Virus', 'Organism Attribute', 'Laboratory or Test Result', 'Receptor', 'Clinical Drug', 'Quantitative Concept', 'Patient or Disabled Group', 'Research Device', 'Qualitative Concept', 'Hazardous or Poisonous Substance', 'Biomedical or Dental Material', 'Human', 'Age Group', 'Plant', 'Physiologic Function', 'Environmental Effect of Humans', 'Disease or Syndrome', 'Chemical', 'Sign or Symptom', 'Anatomical Structure', 'Steroid', 'Organic Chemical', 'Anatomical Abnormality', 'Neoplastic Process'}

# %%
differences = [(cat, test_if_the_same(random_counter, real_counter, cat)) for cat in cats]

# %%
dif = differences[0]

# %%
dif.pvalue
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-98371819c4c7> in <module>()
# ----> 1 dif.pvalue
#
# AttributeError: 'tuple' object has no attribute 'pvalue'

# %%
for dif in differences:
    if dif[1].pvalue < 0.05:
        print(dif[0], "{0:.2E}".format(dif[1].pvalue))
# Out:
# Congenital Abnormality 1.24E-09
# Functional Concept 2.61E-05
# T9998 5.01E-03
# Carbohydrate 2.35E-11
# Injury or Poisoning 2.87E-04
# Indicator, Reagent, or Diagnostic Aid 7.12E-19
# Mental or Behavioral Dysfunction 1.99E-05
# Cell Function 8.96E-11
# Pharmacologic Substance 1.09E-22
# Natural Phenomenon or Process 8.32E-14
# Amino Acid, Peptide, or Protein 1.69E-14
# Health Care Activity 4.53E-03
# Gene or Genome 2.69E-11
# Finding 6.56E-13
# Acquired Abnormality 5.28E-13
# Laboratory Procedure 2.49E-08
# Activity 3.13E-05
# Biologic Function 1.03E-09
# Nucleotide Sequence 4.42E-07
# Molecular Biology Research Technique 7.17E-03
# Biologically Active Substance 1.10E-09
# Vitamin 2.22E-08
# Experimental Model of Disease 1.73E-10
# Neuroreactive Substance or Biogenic Amine 6.07E-07
# Chemical Viewed Structurally 2.72E-16
# Element, Ion, or Isotope 1.31E-05
# Genetic Function 1.66E-08
# Cell or Molecular Dysfunction 1.90E-05
# Therapeutic or Preventive Procedure 2.67E-06
# Organophosphorus Compound 3.94E-13
# Diagnostic Procedure 3.98E-07
# Bacterium 6.54E-04
# Medical Device 2.31E-09
# Inorganic Chemical 9.88E-06
# Group 1.55E-02
# Antibiotic 3.16E-13
# Molecular Function 7.76E-08
# Family Group 3.95E-04
# Individual Behavior 4.51E-02
# Temporal Concept 2.20E-03
# Organism Function 6.30E-04
# Organ or Tissue Function 1.10E-08
# Cell 4.42E-08
# Clinical Attribute 3.21E-07
# Eicosanoid 1.31E-05
# Tissue 1.78E-03
# Organism 5.83E-04
# Pathologic Function 7.56E-05
# Lipid 3.51E-10
# Body Substance 5.54E-08
# Professional or Occupational Group 2.77E-02
# Body Part, Organ, or Organ Component 6.43E-06
# Enzyme 6.10E-13
# Immunologic Factor 2.10E-08
# Hormone 1.31E-08
# Nucleic Acid, Nucleoside, or Nucleotide 1.17E-08
# Virus 6.13E-06
# Organism Attribute 2.63E-03
# Laboratory or Test Result 5.01E-03
# Receptor 1.56E-12
# Clinical Drug 1.75E-13
# Quantitative Concept 2.91E-03
# Hazardous or Poisonous Substance 1.20E-16
# Biomedical or Dental Material 1.98E-06
# Human 5.57E-05
# Physiologic Function 1.88E-15
# Disease or Syndrome 6.88E-11
# Chemical 3.79E-04
# Sign or Symptom 5.83E-04
# Steroid 4.50E-09
# Organic Chemical 7.39E-23
# Anatomical Abnormality 3.14E-08
# Neoplastic Process 2.80E-08

# %%
group_dataframe = pd.read_csv("./Se")

# %%
dif_dataframe = pd.DataFrame()
dif_dataframe["Semantic type(subcategory)"] = pd.Series([dif[0] for dif in differences])
dif_dataframe["P-value"] = pd.Series([dif[1][1] for dif in differences])

# %%
dif_dataframe
# Out:
#                   Semantic type(subcategory)       P-value
# 0                     Congenital Abnormality  1.242932e-09
# 1                         Functional Concept  2.612888e-05
# 2                                      T9998  5.006621e-03
# 3                               Carbohydrate  2.350902e-11
# 4                        Injury or Poisoning  2.868687e-04
# 5                                       Food  9.540133e-02
# 6      Indicator, Reagent, or Diagnostic Aid  7.122747e-19
# 7             Daily or Recreational Activity  1.000000e+00
# 8           Mental or Behavioral Dysfunction  1.987225e-05
# 9                                 Vertebrate  9.999990e-01
# 10                             Cell Function  8.963983e-11
# 11                   Body Location or Region  1.315218e-01
# 12                            Cell Component  5.276084e-02
# 13                   Pharmacologic Substance  1.089912e-22
# 14                                    Animal  3.621837e-01
# 15                            Classification  9.806154e-01
# 16             Natural Phenomenon or Process  8.317050e-14
# 17                      Intellectual Product  9.970286e-01
# 18                     Phenomenon or Process  3.142545e-01
# 19           Amino Acid, Peptide, or Protein  1.685303e-14
# 20                                 Amphibian  1.000000e+00
# 21                      Health Care Activity  4.531558e-03
# 22                            Gene or Genome  2.692005e-11
# 23                                   Finding  6.563278e-13
# 24                      Acquired Abnormality  5.278206e-13
# 25                      Laboratory Procedure  2.493094e-08
# 26                                  Activity  3.130228e-05
# 27                        Molecular Sequence  6.745511e-01
# 28                               Body System  9.999998e-01
# 29                         Biologic Function  1.030751e-09
# ..                                       ...           ...
# 84                                    Enzyme  6.104017e-13
# 85                                    Mammal  7.382602e-01
# 86         Fully Formed Anatomical Structure  1.000000e+00
# 87                        Immunologic Factor  2.096043e-08
# 88                                   Hormone  1.314471e-08
# 89   Nucleic Acid, Nucleoside, or Nucleotide  1.168669e-08
# 90                                     Virus  6.131326e-06
# 91                        Organism Attribute  2.625996e-03
# 92                 Laboratory or Test Result  5.006621e-03
# 93                                  Receptor  1.556272e-12
# 94                             Clinical Drug  1.753694e-13
# 95                      Quantitative Concept  2.914051e-03
# 96                 Patient or Disabled Group  9.560811e-01
# 97                           Research Device  1.000000e+00
# 98                       Qualitative Concept  4.145743e-01
# 99          Hazardous or Poisonous Substance  1.195803e-16
# 100            Biomedical or Dental Material  1.976062e-06
# 101                                    Human  5.574009e-05
# 102                                Age Group  6.342494e-01
# 103                                    Plant  9.560811e-01
# 104                     Physiologic Function  1.883877e-15
# 105           Environmental Effect of Humans  1.000000e+00
# 106                      Disease or Syndrome  6.878888e-11
# 107                                 Chemical  3.793139e-04
# 108                          Sign or Symptom  5.830513e-04
# 109                     Anatomical Structure  1.000000e+00
# 110                                  Steroid  4.502976e-09
# 111                         Organic Chemical  7.394138e-23
# 112                   Anatomical Abnormality  3.137862e-08
# 113                       Neoplastic Process  2.797471e-08
#
# [114 rows x 2 columns]
